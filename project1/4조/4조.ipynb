# %% [markdown]
# # 데이터 셋 불러오기 및 전처리

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

pd.set_option('display.max_columns', None)
pr=pd.read_csv('prep.csv')
pr
# Out:
#     year  std_total  std_exp  hiv  smoke  drink  stress  depress  \
# 0   2000        NaN      NaN    2    NaN    NaN     NaN      NaN
# 1   2001        NaN      NaN    6    NaN    NaN     NaN      NaN
# 2   2002      0.028      NaN    5    NaN    NaN     NaN      NaN
# 3   2003      0.021      NaN    6    NaN    NaN     NaN      NaN
# 4   2004      0.014      NaN   12    NaN    NaN     NaN      NaN
# 5   2005      0.009      NaN   16    NaN    NaN     NaN      NaN
# 6   2006      0.006     0.13   13   12.8   28.6    46.5     41.4
# 7   2007      0.006     0.12   17   13.3   27.8    46.5     41.3
# 8   2008      0.006     0.11   20   12.8   24.5    43.7     38.8
# 9   2009      0.005     0.10   27   12.8   21.1    43.2     37.5
# 10  2010      0.005     0.09   28   12.1   21.1    43.8     37.4
# 11  2011      0.006     0.11   40   12.1   20.6    42.0     32.8
# 12  2012      0.006     0.13   32   11.4   19.4    41.9     30.5
# ...

# %%
pr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19 entries, 0 to 18
# Data columns (total 37 columns):
# year                                   19 non-null int64
# std_total                              17 non-null float64
# std_exp                                13 non-null float64
# hiv                                    19 non-null int64
# smoke                                  13 non-null float64
# drink                                  13 non-null float64
# stress                                 13 non-null float64
# depress                                13 non-null float64
# sex_frequency                          13 non-null float64
# contraception                          7 non-null float64
# abortion                               9 non-null float64
# obesity                                13 non-null float64
# teen_crime                             11 non-null float64
# tuberculosis                           18 non-null float64
# ...

# %%
pr.isnull().sum()
# Out:
# year                                    0
# std_total                               2
# std_exp                                 6
# hiv                                     0
# smoke                                   6
# drink                                   6
# stress                                  6
# depress                                 6
# sex_frequency                           6
# contraception                          12
# abortion                               10
# obesity                                 6
# teen_crime                              8
# tuberculosis                            1
# pre_puberty                            10
# single                                  5
# private_edu                             7
# exercise3_week                          5
# basic_livelihood_security_recipient     1
# culture_fac                             3
# welfare_fac                             4
# sports_fac                              4
# ...

# %%
df=pr.iloc[9:]
df
# Out:
#     year  std_total  std_exp  hiv  smoke  drink  stress  depress  \
# 9   2009      0.005     0.10   27   12.8   21.1    43.2     37.5
# 10  2010      0.005     0.09   28   12.1   21.1    43.8     37.4
# 11  2011      0.006     0.11   40   12.1   20.6    42.0     32.8
# 12  2012      0.006     0.13   32   11.4   19.4    41.9     30.5
# 13  2013      0.006     0.11   53    9.7   16.3    41.4     30.9
# 14  2014      0.007     0.13   40    9.2   16.7    37.0     26.7
# 15  2015      0.013     0.26   42    7.8   16.7    35.4     23.6
# 16  2016      0.018     0.39   36    6.3   15.0    37.4     25.5
# 17  2017      0.018     0.35   34    6.4   16.1    37.2     25.1
# 18  2018      0.026     0.46   19    6.7   16.9    40.4     27.1
#
#     sex_frequency  contraception  abortion  obesity  teen_crime  tuberculosis  \
# 9             5.1           80.0       NaN      5.1       17.33        2421.0
# 10            5.3            NaN     148.0      5.3       13.90        2338.0
# ...

# %%
df['contraception']=df['contraception'].fillna(method='ffill')
df['welfare_fac']=df['welfare_fac'].fillna(method='ffill')
df['sports_fac']=df['sports_fac'].fillna(method='ffill')
df['abortion']=df['abortion'].fillna(method='bfill')
df['pre_puberty'] = df['pre_puberty'].fillna(method='bfill')
# Out:
# C:\Users\ICT01_07\Anaconda\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\ICT01_07\Anaconda\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\ICT01_07\Anaconda\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
df=df.fillna(df.mean())
df
# Out:
#     year  std_total  std_exp  hiv  smoke  drink  stress  depress  \
# 9   2009      0.005     0.10   27   12.8   21.1    43.2     37.5
# 10  2010      0.005     0.09   28   12.1   21.1    43.8     37.4
# 11  2011      0.006     0.11   40   12.1   20.6    42.0     32.8
# 12  2012      0.006     0.13   32   11.4   19.4    41.9     30.5
# 13  2013      0.006     0.11   53    9.7   16.3    41.4     30.9
# 14  2014      0.007     0.13   40    9.2   16.7    37.0     26.7
# 15  2015      0.013     0.26   42    7.8   16.7    35.4     23.6
# 16  2016      0.018     0.39   36    6.3   15.0    37.4     25.5
# 17  2017      0.018     0.35   34    6.4   16.1    37.2     25.1
# 18  2018      0.026     0.46   19    6.7   16.9    40.4     27.1
#
#     sex_frequency  contraception  abortion  obesity  teen_crime  tuberculosis  \
# 9             5.1           80.0     148.0      5.1       17.33        2421.0
# 10            5.3           80.0     148.0      5.3       13.90        2338.0
# ...

# %%
df.isnull().sum()
# Out:
# year                                   0
# std_total                              0
# std_exp                                0
# hiv                                    0
# smoke                                  0
# drink                                  0
# stress                                 0
# depress                                0
# sex_frequency                          0
# contraception                          0
# abortion                               0
# obesity                                0
# teen_crime                             0
# tuberculosis                           0
# pre_puberty                            0
# single                                 0
# private_edu                            0
# exercise3_week                         0
# basic_livelihood_security_recipient    0
# culture_fac                            0
# welfare_fac                            0
# sports_fac                             0
# park                                   0
# ...

# %%
corr=df.corr(method='pearson')
corr
# Out:
#                                          year  std_total   std_exp       hiv  \
# year                                 1.000000   0.900230  0.900916 -0.064110
# std_total                            0.900230   1.000000  0.989013 -0.408142
# std_exp                              0.900916   0.989013  1.000000 -0.365968
# hiv                                 -0.064110  -0.408142 -0.365968  1.000000
# smoke                               -0.970646  -0.867905 -0.894358 -0.010824
# drink                               -0.861829  -0.631646 -0.672601 -0.343173
# stress                              -0.731934  -0.495052 -0.548646 -0.301736
# depress                             -0.887595  -0.662545 -0.699605 -0.229669
# sex_frequency                        0.244750   0.303176  0.187652 -0.185626
# contraception                        0.256479   0.617948  0.570995 -0.680483
# abortion                            -0.980394  -0.927460 -0.933193  0.184504
# ...

# %%
del df['year']

# %%
df_ext = df[['std_total','std_exp', 'contraception', 'abortion','obesity','tuberculosis','pre_puberty','park','internet','per_capita_income','cosmetic']]
df_ext # 특정 변수만 골라낸 것
# Out:
#     std_total  std_exp  contraception  abortion  obesity  tuberculosis  \
# 9       0.005     0.10           80.0     148.0      5.1        2421.0
# 10      0.005     0.09           80.0     148.0      5.3        2338.0
# 11      0.006     0.11           80.0     143.0      5.6        2335.0
# 12      0.006     0.13           77.1     129.0      6.2        1829.0
# 13      0.006     0.11           77.1     126.0      6.6        1436.0
# 14      0.007     0.13           77.1      95.0      6.9        1246.0
# 15      0.013     0.26           79.6      83.0      7.5        1142.0
# 16      0.018     0.39           79.6      68.0      9.1         852.0
# 17      0.018     0.35           79.6      57.0     10.0         697.0
# 18      0.026     0.46           82.3      45.0     10.8         474.0
#
#     pre_puberty  park  internet  per_capita_income    cosmetic
# 9      0.413820   8.1      77.2              19152   5534176.0
# ...

# %% [markdown]
# # StandardScaler, MinmaxScaler

# %%
from sklearn.preprocessing import StandardScaler
std_scaler=StandardScaler(df_ext)

std_scaler
# Out:
# StandardScaler(copy=    std_total  std_exp  contraception  abortion  obesity  tuberculosis  \
# 9       0.005     0.10           80.0     148.0      5.1        2421.0
# 10      0.005     0.09           80.0     148.0      5.3        2338.0
# 11      0.006     0.11           80.0     143.0      5.6        2335.0
# 12      0.006     0.13           77.1     129.0      6.2        1829.0
# 13      0.006     0.11           77.1     126.0      6.6        1436.0
# 14      0.007     0.13           77.1      95.0      6.9        1246.0
# 15      0.013     0.26           79.6      83.0      7.5        1142.0
# 16      0.018     0.39           79.6      68.0      9.1         852.0
# 17      0.018     0.35           79.6      57.0     10.0         697.0
# 18      0.026     0.46           82.3      45....
#     pre_puberty  park  internet  per_capita_income    cosmetic
# 9      0.413820   8.1      77.2              19152   5534176.0
# 10     0.413820   8.4      77.8              23083   6308350.0
# ...

# %%
from sklearn.preprocessing import minmax_scale

df_minmax = minmax_scale(df_ext, axis=0, copy=True)

df2 = pd.DataFrame(df_minmax, columns=df_ext.columns, index = list(df_ext.index.values))
df = df2
df
# Out:
#     std_total   std_exp  contraception  abortion   obesity  tuberculosis  \
# 9    0.000000  0.027027       0.557692  1.000000  0.000000      1.000000
# 10   0.000000  0.000000       0.557692  1.000000  0.035088      0.957370
# 11   0.047619  0.054054       0.557692  0.951456  0.087719      0.955829
# 12   0.047619  0.108108       0.000000  0.815534  0.192982      0.695942
# 13   0.047619  0.054054       0.000000  0.786408  0.263158      0.494093
# 14   0.095238  0.108108       0.000000  0.485437  0.315789      0.396507
# 15   0.380952  0.459459       0.480769  0.368932  0.421053      0.343092
# 16   0.619048  0.810811       0.480769  0.223301  0.701754      0.194145
# 17   0.619048  0.702703       0.480769  0.116505  0.859649      0.114535
# 18   1.000000  1.000000       1.000000  0.000000  1.000000      0.000000
#
#     pre_puberty  park  internet  per_capita_income  cosmetic
# 9      0.000000  0.00  0.000000           0.000000  0.000000
# ...

# %%
df.hist(bins=50, figsize=(20,15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002D4C9F100C8>,
# ...
#       dtype=object)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

output = df[['std_total','std_exp', 'contraception', 'abortion','obesity','tuberculosis','pre_puberty','park','internet','per_capita_income','cosmetic']]
output
# Out:
#     std_total   std_exp  contraception  abortion   obesity  tuberculosis  \
# 9    0.000000  0.027027       0.557692  1.000000  0.000000      1.000000
# 10   0.000000  0.000000       0.557692  1.000000  0.035088      0.957370
# 11   0.047619  0.054054       0.557692  0.951456  0.087719      0.955829
# 12   0.047619  0.108108       0.000000  0.815534  0.192982      0.695942
# 13   0.047619  0.054054       0.000000  0.786408  0.263158      0.494093
# 14   0.095238  0.108108       0.000000  0.485437  0.315789      0.396507
# 15   0.380952  0.459459       0.480769  0.368932  0.421053      0.343092
# 16   0.619048  0.810811       0.480769  0.223301  0.701754      0.194145
# 17   0.619048  0.702703       0.480769  0.116505  0.859649      0.114535
# 18   1.000000  1.000000       1.000000  0.000000  1.000000      0.000000
#
#     pre_puberty  park  internet  per_capita_income  cosmetic
# 9      0.000000  0.00  0.000000           0.000000  0.000000
# ...

# %%
#스캐터플롯
import seaborn as sns
sns.pairplot(output, diag_kind='hist')
plt.show()

# %%
cmap=sns.light_palette("darkgray")
plt.subplots(figsize=(20,20))
sns.heatmap(output.corr(),annot=True,cmap=cmap)
plt.show()

# %%
output=output.drop(['std_total'], axis=1)
output
# Out:
#      std_exp  contraception  abortion   obesity  tuberculosis  pre_puberty  \
# 9   0.027027       0.557692  1.000000  0.000000      1.000000     0.000000
# 10  0.000000       0.557692  1.000000  0.035088      0.957370     0.000000
# 11  0.054054       0.557692  0.951456  0.087719      0.955829     0.174969
# 12  0.108108       0.000000  0.815534  0.192982      0.695942     0.279279
# 13  0.054054       0.000000  0.786408  0.263158      0.494093     0.409701
# 14  0.108108       0.000000  0.485437  0.315789      0.396507     0.497040
# 15  0.459459       0.480769  0.368932  0.421053      0.343092     0.574727
# 16  0.810811       0.480769  0.223301  0.701754      0.194145     0.729997
# 17  0.702703       0.480769  0.116505  0.859649      0.114535     0.871622
# 18  1.000000       1.000000  0.000000  1.000000      0.000000     1.000000
#
#     park  internet  per_capita_income  cosmetic
# 9   0.00  0.000000           0.000000  0.000000
# ...

# %% [markdown]
# # 다중공선성 제거

# %%
#다중공선성
from sklearn.model_selection import train_test_split
import statsmodels.api as sm

lm = sm.OLS(output['std_exp'],output[['contraception', 'abortion','obesity','tuberculosis','pre_puberty','park','internet','per_capita_income', 'cosmetic']])
results = lm.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                std_exp   R-squared (uncentered):                   1.000
# Model:                            OLS   Adj. R-squared (uncentered):              0.999
# Method:                 Least Squares   F-statistic:                              816.6
# Date:                Thu, 23 Jan 2020   Prob (F-statistic):                      0.0272
# Time:                        09:03:29   Log-Likelihood:                          37.475
# No. Observations:                  10   AIC:                                     -56.95
# Df Residuals:                       1   BIC:                                     -54.23
# Df Model:                           9
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# ...

# %%
# output_1 = output.drop(['std_exp'], axis=1)
# output_1.plot(figsize=(20,10))
# #output

# %%
from patsy import *
from statsmodels.stats.outliers_influence import variance_inflation_factor

features='contraception+abortion+obesity+tuberculosis+pre_puberty+park+internet+per_capita_income+cosmetic'
y,X=dmatrices("std_exp~"+features,data=output,return_type="dataframe")

vif = pd.DataFrame()
vif["VIF Factor"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif["features"] = X.columns
vif
# Out:
#     VIF Factor           features
# 0  8935.384812          Intercept
# 1    21.826139      contraception
# 2    53.654995           abortion
# 3  2620.181528            obesity
# 4  1131.574532       tuberculosis
# 5   735.238406        pre_puberty
# 6   431.296510               park
# 7  1934.574741           internet
# 8   110.414280  per_capita_income
# 9    91.088929           cosmetic

# %%
from sklearn.feature_selection import RFE 
from sklearn.svm import SVR


X=output.iloc[:,1:]
y=output['std_exp']
estimator = SVR(kernel = 'linear')
selector =RFE(estimator,8,step=1)
selector = selector.fit(X,y)
selector.support_
selector.ranking_
# Out:
# array([1, 1, 1, 1, 1, 1, 1, 2, 1])

# %%
second = sorted(zip(map(lambda x: x==1,selector.ranking_),features),reverse = True)
second
# Out:
# [(True, 't'),
#  (True, 'r'),
#  (True, 'p'),
#  (True, 'o'),
#  (True, 'n'),
#  (True, 'c'),
#  (True, 'c'),
#  (True, 'a'),
#  (False, 'e')]

# %%
output = output.drop(['per_capita_income'], axis=1)
output
# Out:
#      std_exp  contraception  abortion   obesity  tuberculosis  pre_puberty  \
# 9   0.027027       0.557692  1.000000  0.000000      1.000000     0.000000
# 10  0.000000       0.557692  1.000000  0.035088      0.957370     0.000000
# 11  0.054054       0.557692  0.951456  0.087719      0.955829     0.174969
# 12  0.108108       0.000000  0.815534  0.192982      0.695942     0.279279
# 13  0.054054       0.000000  0.786408  0.263158      0.494093     0.409701
# 14  0.108108       0.000000  0.485437  0.315789      0.396507     0.497040
# 15  0.459459       0.480769  0.368932  0.421053      0.343092     0.574727
# 16  0.810811       0.480769  0.223301  0.701754      0.194145     0.729997
# 17  0.702703       0.480769  0.116505  0.859649      0.114535     0.871622
# 18  1.000000       1.000000  0.000000  1.000000      0.000000     1.000000
#
#     park  internet  cosmetic
# 9   0.00  0.000000  0.000000
# 10  0.15  0.041958  0.172084
# 11  0.10  0.055944  0.234639
# ...

# %%
lm = sm.OLS(output['std_exp'],output[['contraception', 'abortion','obesity','tuberculosis','pre_puberty','park','internet','cosmetic']])
results = lm.fit()
results.summary()
# Out:
# C:\Users\ICT01_07\Anaconda\lib\site-packages\scipy\stats\stats.py:1450: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=10
#   "anyway, n=%i" % int(n))
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                std_exp   R-squared (uncentered):                   0.994
# Model:                            OLS   Adj. R-squared (uncentered):              0.968
# Method:                 Least Squares   F-statistic:                              38.81
# Date:                Thu, 23 Jan 2020   Prob (F-statistic):                      0.0254
# Time:                        09:35:15   Log-Likelihood:                          18.219
# No. Observations:                  10   AIC:                                     -20.44
# Df Residuals:                       2   BIC:                                     -18.02
# Df Model:                           8
# Covariance Type:            nonrobust
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn import linear_model

X = output.drop(['std_exp'], axis=1)
y = output['std_exp']

linear_regression = linear_model.LinearRegression()
linear_regression.fit(X= pd.DataFrame(X), y =y) # 모델 생성
my_prediction = linear_regression.predict(X = pd.DataFrame(X)) # X 값을 넣어서 예측한 값 = predict

print('intercept = ', linear_regression.intercept_) # 절편
print('coef = ', linear_regression.coef_)           # 계수

print('---------------------------------------------------------')

# 적합도 검증 - 잔차
residuals = y - my_prediction
print(residuals.describe())


print('---------------------------------------------------------')
# 적합도 검증 - 결정계수 확인
SSE = (residuals**2).sum()
SST = ((y-y.mean())**2).sum()
R_squared = 1 - (SSE/SST)
print('R_squared = ', R_squared)

print('---------------------------------------------------------')
from sklearn.metrics import mean_squared_error

print('score = ', linear_regression.score(X = pd.DataFrame(X), y=y))
print('Mean_Squared_Error(MSE) = ', mean_squared_error(my_prediction, y)) # 평균제곱오차
print('RMSE = ', mean_squared_error(my_prediction, y)**0.5)              # 평균제곱근 편차
# Out:
# intercept =  1.548417257619099
# coef =  [ 0.39656461 -0.23818268  4.5517649  -1.50826464 -1.55506024 -1.5104049
#  -3.07356341  0.65327994]
# ---------------------------------------------------------
# count    1.000000e+01
# mean    -5.828671e-17
# std      1.252687e-02
# min     -2.183762e-02
# 25%     -6.666412e-03
# 50%     -1.837913e-04
# 75%      5.105640e-03
# max      2.113406e-02
# Name: std_exp, dtype: float64
# ---------------------------------------------------------
# R_squared =  0.998902762645855
# ---------------------------------------------------------
# score =  0.998902762645855
# Mean_Squared_Error(MSE) =  0.00014123023679612627
# RMSE =  0.011884032850683571

# %%
print(residuals)
plt.plot(residuals, color="green")
# Out:
# 9     0.003896
# 10   -0.004036
# 11   -0.004747
# 12    0.005509
# 13    0.003669
# 14   -0.021838
# 15    0.021134
# 16   -0.007306
# 17    0.014718
# 18   -0.010998
# Name: std_exp, dtype: float64

# %%
# from sklearn import linear_model
# import numpy as np
# import pandas as pd
# import matplotlib
# import matplotlib.pyplot as plt
# %matplotlib inline
# matplotlib.style.use('ggplot')

# # y와 변수들간의 상관관계 살피기
# plt.scatter(y,X['tuberculosis'],alpha=0.5, color = "red")
# plt.scatter(y,X['pre_puberty'], alpha=0.5, color = "green")
# plt.scatter(y,X['internet'], alpha=0.5, color="purple")
# plt.show

# %%
output
# Out:
#      std_exp  contraception  abortion   obesity  tuberculosis  pre_puberty  \
# 9   0.027027       0.557692  1.000000  0.000000      1.000000     0.000000
# 10  0.000000       0.557692  1.000000  0.035088      0.957370     0.000000
# 11  0.054054       0.557692  0.951456  0.087719      0.955829     0.174969
# 12  0.108108       0.000000  0.815534  0.192982      0.695942     0.279279
# 13  0.054054       0.000000  0.786408  0.263158      0.494093     0.409701
# 14  0.108108       0.000000  0.485437  0.315789      0.396507     0.497040
# 15  0.459459       0.480769  0.368932  0.421053      0.343092     0.574727
# 16  0.810811       0.480769  0.223301  0.701754      0.194145     0.729997
# 17  0.702703       0.480769  0.116505  0.859649      0.114535     0.871622
# 18  1.000000       1.000000  0.000000  1.000000      0.000000     1.000000
#
#     park  internet  cosmetic
# 9   0.00  0.000000  0.000000
# 10  0.15  0.041958  0.172084
# 11  0.10  0.055944  0.234639
# ...

# %%
# 다중 선형 #
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

y = output['std_exp']
x = output.drop(['std_exp'] , axis = 1)

x_train, x_test, y_train, y_test = train_test_split(x, y, random_state=42)

mlr = LinearRegression().fit(x_train, y_train)

print("lr.coef_: {}".format(mlr.coef_))           # 계수
print("lr.intercept_: {}".format(mlr.intercept_)) # 절편


# 방정식 도출
# y = -0.21024618*X1 -1.14731841*X2 + 1.40624312*X3 +1.02539156*X4 -0.76103972*X5
#        -0.13070707*X6 +0.34298343*X7 + 0.08655986*X8 + 0.2662065538832491
# Out:
# lr.coef_: [-0.21024618 -1.14731841  1.40624312  1.02539156 -0.76103972 -0.13070707
#   0.34298343  0.08655986]
# lr.intercept_: 0.2662065538832491

# %% [markdown]
# # 모델 생성, MSE 계산

# %% [markdown]
# ## 모델 1. 선형회귀

# %%
from sklearn.linear_model import LinearRegression

mlr = LinearRegression().fit(x_train, y_train) # 선형회귀 모델 생성
y_pred = mlr.predict(x_test) # 예측값 생성

# %%
# training data mse

X_pred = mlr.predict(x_train) # x_train의 예측값

print("MSE : ", mean_squared_error(y_train, X_pred)) # train data 간의 mse
# Out:
# MSE :  5.557683553803166e-32

# %%
# test data mse
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

print("MSE : ",mean_squared_error(y_test, y_pred)) # test data(실제값과 예측값)의 mse(평균제곱오차)

print("RMSE : ",np.sqrt(mean_squared_error(y_test,y_pred))) # test data의 rmse(평균제곱근편차)

print(r2_score(y_test,y_pred)) # r2_score() = explained_variance_score


LR = pd.DataFrame({'y_data':y_test,'preds':y_pred})  # 높으면서 위 두개의 차이 적어야한다. 
LR.corr() # 두 변수( y_data, preds 간의 상관계수 구하기 => 0.98249
# Out:
# MSE :  0.04668378850308564
# RMSE :  0.21606431566338213
# 0.5108920423924164
#          y_data    preds
# y_data  1.00000  0.98249
# preds   0.98249  1.00000

# %%
# training data set의 MSE : 5.557683553803166e-32
# test data set의 MSE : 0.04668378850308564
# -> 차이가 크다.

# %% [markdown]
# ## 모델 2. 릿지 회귀

# %%
from sklearn.linear_model import Ridge

ridge = Ridge(alpha=0.1).fit(x_train, y_train)
y_pred = ridge.predict(x_test)

# %%
# training data mse
X_pred = ridge.predict(x_train)
print("MSE : ", mean_squared_error(y_train, X_pred))
# Out:
# MSE :  0.004651654811485968

# %%
# test data mse

print("MSE : ",mean_squared_error(y_test, y_pred))

print("RMSE : ",np.sqrt(mean_squared_error(y_test,y_pred)))

print(r2_score(y_test,y_pred))

Rid = pd.DataFrame({'y_data':y_test,'preds':y_pred})  # 높으면서 위 두개의 차이 적어야한다. 
Rid.corr()
# Out:
# MSE :  0.013868319559888315
# RMSE :  0.11776382959078868
# 0.8547010499171905
#           y_data     preds
# y_data  1.000000  0.982355
# preds   0.982355  1.000000

# %%
# training data set의 MSE : 0.004651654811485968
# test data set의 MSE : 0.013868319559888315
# -> 차이 : 0.0092

# %% [markdown]
# ## 모델 3. 라쏘 회귀

# %%
from sklearn.linear_model import Lasso

lasso = Lasso(alpha=0.01, max_iter=100000).fit(x_train, y_train)
y_pred = lasso.predict(x_test)

# %%
# training data mse
X_pred = lasso.predict(x_train)
print("MSE : ", mean_squared_error(y_train, X_pred))
# Out:
# MSE :  0.004465068139649196

# %%
# test data mse
print("MSE : ",mean_squared_error(y_test, y_pred))

print("RMSE : ",np.sqrt(mean_squared_error(y_test,y_pred)))

print(r2_score(y_test,y_pred))

Lasso = pd.DataFrame({'y_data':y_test,'preds':y_pred})  # 높으면서 위 두개의 차이 적어야한다. 
Lasso.corr()
# Out:
# MSE :  0.0258626352891059
# RMSE :  0.16081864098762277
# 0.7290361144582704
#           y_data     preds
# y_data  1.000000  0.946145
# preds   0.946145  1.000000

# %%
# training data set의 MSE : 0.004465068139649196
# test data set의 MSE : 0.0258626352891059
# -> 차이 : 0.0213

# %% [markdown]
# ## 모델 4. 랜덤포레스트

# %%
from sklearn.ensemble import RandomForestRegressor

model = RandomForestRegressor(n_estimators=100)
model.fit(x_train, y_train)

y_pred = model.predict(x_test)

#훈련 mse

X_pred = model.predict(x_train)
print("MSE : ",mean_squared_error(y_train, X_pred))

#print(x_train.shape)
#print(y_train.shape)
# Out:
# MSE :  0.0029300323489512793

# %%
# test mse
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

print("MSE : ",mean_squared_error(y_test, y_pred))
print("RMSE : ",np.sqrt(mean_squared_error(y_test,y_pred)))
print("r2score : ", r2_score(y_test,y_pred))

fin=pd.DataFrame({'y_data':y_test,'preds':y_pred})  # 높으면서 위 두개의 차이 적어야한다. 
fin.corr()
# Out:
# MSE :  0.01887628439250057
# RMSE :  0.13739099094373172
# r2score :  0.802232397959184
#           y_data     preds
# y_data  1.000000  0.979545
# preds   0.979545  1.000000

# %%
# training data set의 MSE : 0.0029300323489512793
# test data set의 MSE : 0.01887628439250057
# -> 차이 : 0.0159

# %% [markdown]
# ## 모델 5. XGboost

# %%
# xgboost # 

import xgboost as xgb
from sklearn.metrics import mean_squared_error

# 데이터 프레임은 ndarray + dic : 중복가능/순서보장


X=output.iloc[:,1:]
y=output.iloc[:,0]
    
data_dmatrix = xgb.DMatrix(data = X,label =y)  #xg 전용 매트릭스로 바꿔줘야함 #DMatrix 얘때문에 속도가 빠름  #label은 종속변수 
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,random_state=42)

#objective = 'reg:linear' 선형 회귀방식  # tree방식도 있음
# learning_rate(학습률) :경사하강법에 의해 동작하는 애들이 등장 
#max_depth 과적합 방지 
xg_reg = xgb.XGBRegressor(objective = 'reg:linear',colsample_bytree =0.3,  #col sample이 몇갠지
                         learning_rate =0.1, max_depth = 5,alpha =10,n_estimators =10)

xg = xg_reg.fit(X_train,y_train)
preds=xg_reg.predict(X_test)# ybar(예측치)가 결정됨


# training data mse
X_pred = xg.predict(x_train)
print("MSE : ",mean_squared_error(y_train, X_pred))
# Out:
# [09:09:09] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# MSE :  0.03574980513951602
# C:\Users\ICT01_07\Anaconda\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# C:\Users\ICT01_07\Anaconda\lib\site-packages\xgboost\core.py:588: FutureWarning: Series.base is deprecated and will be removed in a future version
#   data.base is not None and isinstance(data, np.ndarray) \

# %%
# test data mse
print("MSE : ",mean_squared_error(y_test, preds))

print("RMSE : ",np.sqrt(mean_squared_error(y_test,preds)))

print(r2_score(y_test,y_pred))

XG = pd.DataFrame({'y_data':y_test,'preds':y_pred})  # 높으면서 위 두개의 차이 적어야한다. 
XG.corr()
# Out:
# MSE :  0.06437427935686806
# RMSE :  0.25372086898177704
# 0.802232397959184
#           y_data     preds
# y_data  1.000000  0.979545
# preds   0.979545  1.000000

# %%
# training data set의 MSE : 0.03574980513951602
# test data set의 MSE : 0.06437427935686806
# -> 차이 : 0.0286

# %%
# 1. 선형회귀 - train과 test mse 차이 : 큼          / corr : 0.98249
# 2. 릿지회귀 - train과 test mse 차이 : 0.0092     / corr : 0.982355
# 3. 라쏘회귀 - train과 test mse 차이 : 0.0213     / corr : 0.946145
# 4. 랜덤포레스트 - train과 test mse 차이 : 0.0159 / corr : 0.979545
# 5. XGboost - train과 test mse 차이 : 0.0286      / corr : 0.979545

# 릿지, 랜덤포레스트 corr 차이 : 0.0054
# 		mse 차이 : 0.0004


# corr : 예측값과 실제값 사이에 관계가 있다.
# 'train과 test mse 차이'가 작을수록 예측성이 좋다 * 작은 것의 기준은 team by team

# %% [markdown]
# # 매개변수 과대적합과 검증 세트

# %%
from sklearn.svm import SVR

x = output.drop(['std_exp'] , axis = 1)
y = output['std_exp']

# 데이터를 훈련+검증, 테스트 세트로 분할
X_trainval, X_test, y_trainval, y_test = train_test_split(
    x,y, random_state=42)

# 훈련+검증 세트를 훈련, 검증 세트로 분할
X_train, X_valid, y_train, y_valid = train_test_split(
    X_trainval, y_trainval, random_state=42)

print("훈련 세트의 크기: {}    검증 세트의 크기 : {}    테스트 세트의 크기 : {} \n".format(X_train.shape[0],
                                                       X_valid.shape[0], X_test.shape[0]))
# Out:
# 훈련 세트의 크기: 5    검증 세트의 크기 : 2    테스트 세트의 크기 : 3

# %%
best_score = 0

for gamma in [0.001, 0.01, 0.1, 1, 10, 100]:
    for C in [0.001, 0.01, 0.1, 1, 10, 100]:
        
        # 매개변수의 각 조합에 대해 SVR 훈련
        svm = SVR(gamma = gamma, C=C)
        svm.fit(X_train, y_train)
        
        #검증 세트로 SVC 평가
        score = svm.score(X_valid, y_valid)
        
        # 점수가 더 높으면 매개변수와 함께 기록
        if score > best_score:
            best_score = score
            best_parameters = {'C':C, 'gamma':gamma}

# %%
# 훈련 세트와 검증 세트를 합쳐 모델을 다시 만든 후 테스트 세트를 사용해 평가한다.

svm = SVR(**best_parameters)
svm.fit(X_trainval, y_trainval)
test_score = svm.score(X_test, y_test)
print("검증 세트에서 최고 점수 : {:.2f}".format(best_score))
print("최적 매개변수:", best_parameters)
print("최적 매개변수에서 테스트 세트 점수: {:.2f}".format(test_score))
# Out:
# 검증 세트에서 최고 점수 : 0.83
# 최적 매개변수: {'C': 10, 'gamma': 0.1}
# 최적 매개변수에서 테스트 세트 점수: 0.84

# %%
#  ↑ 새로운 데이터에 대해 88%만 정확하게 예측한다?

# %% [markdown]
# # 시각화

# %%
# y와 x 변수간 (각각) 선형 관계 
# 두번째는 y와 전체

# %matplotlib inline
import seaborn as sns
import matplotlib.pyplot as plt

plt.subplot(1, 4, 1)   # 1 x 3 그래프 배열에서 첫 번째 그래프
sns.regplot('contraception', 'std_exp', output, color='red')

plt.subplot(1, 4, 2)   # 1 x 3 그래프 배열에서 두 번째 그래프
sns.regplot('abortion', 'std_exp', output, color='blue')

plt.subplot(1, 4, 3)   # 1 x 3 그래프 배열에서 세 번째 그래프
sns.regplot('obesity', 'std_exp', output, color='green')

plt.subplot(1, 4, 4)   # 1 x 3 그래프 배열에서 세 번째 그래프
sns.regplot('tuberculosis', 'std_exp', output, color='orange')

plt.show()

output.plot()

# %%
plt.subplot(1, 4, 1)   # 1 x 3 그래프 배열에서 세 번째 그래프
sns.regplot('pre_puberty', 'std_exp', output, color='purple')

plt.subplot(1, 4, 2)   # 1 x 3 그래프 배열에서 세 번째 그래프
sns.regplot('park', 'std_exp', output, color='pink')

plt.subplot(1, 4, 3)   # 1 x 3 그래프 배열에서 세 번째 그래프
sns.regplot('internet', 'std_exp', output, color='black')

plt.subplot(1, 4, 4)   # 1 x 3 그래프 배열에서 세 번째 그래프
sns.regplot('cosmetic', 'std_exp', output, color='yellowgreen')

# %%
# 2 #
# https://www.slideshare.net/TaeYoungLee1/1-115587182
# y를 기준으로 두 x변수 간의 관계

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.rcParams['figure.figsize'] = [12, 8]

#X = output_ext.iloc[:,1]
#y = output_ext.iloc[:,0]

sns.lmplot('park','std_exp', hue =  'pre_puberty', data=output) 

#plt.title('Scatter Plot with Regression Line by regplot()', fontsize=20)

plt.show()

# %%
# 3 # 
# x 변수간 상관관계
from pandas.plotting import scatter_matrix
scatter_matrix(output,  alpha=0.5,  figsize=(8, 8),  diagonal='kde')
plt.show()

# %%
output
# Out:
#      std_exp  contraception  abortion   obesity  tuberculosis  pre_puberty  \
# 9   0.027027       0.557692  1.000000  0.000000      1.000000     0.000000
# 10  0.000000       0.557692  1.000000  0.035088      0.957370     0.000000
# 11  0.054054       0.557692  0.951456  0.087719      0.955829     0.174969
# 12  0.108108       0.000000  0.815534  0.192982      0.695942     0.279279
# 13  0.054054       0.000000  0.786408  0.263158      0.494093     0.409701
# 14  0.108108       0.000000  0.485437  0.315789      0.396507     0.497040
# 15  0.459459       0.480769  0.368932  0.421053      0.343092     0.574727
# 16  0.810811       0.480769  0.223301  0.701754      0.194145     0.729997
# 17  0.702703       0.480769  0.116505  0.859649      0.114535     0.871622
# 18  1.000000       1.000000  0.000000  1.000000      0.000000     1.000000
#
#     park  internet  cosmetic
# 9   0.00  0.000000  0.000000
# 10  0.15  0.041958  0.172084
# 11  0.10  0.055944  0.234639
# ...
